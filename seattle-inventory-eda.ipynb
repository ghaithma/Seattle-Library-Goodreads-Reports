# %%
import pandas as pd

# %%
library_df = pd.read_csv('./library-collection-inventory.csv')

# %%
library_df.iloc[1785509]
# Out:
# BibNum                                               3122518
# Title              Gor︠i︡achiĭ pepel / Vsevolod Ovchinnikov.
# Author                                Ovchinnikov, Vsevolod.
# ISBN                                           9785170873227
# PublicationYear                                      c20151.
# Publisher                               AST : Astrelʹ ; VKT,
# Subjects                              Authors Russian Travel
# ItemType                                                acbk
# ItemCollection                                          caln
# FloatingItem                                             NaN
# ItemLocation                                             cen
# ReportDate                           2017-10-01T00:00:00.000
# ItemCount                                                  1
# Name: 1785509, dtype: object

# %%
many_isnbs = library_df[library_df.ISBN.str.split(',').str.len() > 10]

# %%
many_isnbs.shape
# Out:
# (12841, 13)

# %%
lots_df = many_isnbs[many_isnbs.ISBN.str.split(',').str.len() > 20]

# %%
lots_df.shape
# Out:
# (1052, 13)

# %%
lots_df[lots_df.ISBN.str.split(',').str.len() > 86]
# Out:
#            BibNum                                              Title  \
# 799702    3021717  National intelligencer & Washington advertiser...
# 2587594   3021717  National intelligencer & Washington advertiser...
# 2897383   3021717  National intelligencer & Washington advertiser...
# 5295393   3021717  National intelligencer & Washington advertiser...
# 6471632   3021717  National intelligencer & Washington advertiser...
# 7320511   3021717  National intelligencer & Washington advertiser...
# 8502188   3021717  National intelligencer & Washington advertiser...
# 10164244  3021717  National intelligencer & Washington advertiser...
# 11824308  3021717  National intelligencer & Washington advertiser...
# 12519593  3021717  National intelligencer & Washington advertiser...
# 13509306  3021717  National intelligencer & Washington advertiser...
# 15148180  3021717  National intelligencer & Washington advertiser...
# 16830083  3021717  National intelligencer & Washington advertiser...
# ...

# %%
lots_df.shape
# Out:
# (1052, 13)

# %%
lots_df.drop_duplicates(subset=['BibNum'], keep='last').shape
# Out:
# (26, 13)

# %%
library_df.BibNum.duplicated().sum()
# Out:
# np.int64(34742422)

# %%
library_df.shape
# Out:
# (35531308, 13)

# %%
library_df.duplicated(subset=['BibNum']).sum()
# Out:
# 221 ms ± 33.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Fully duplicated: 59904
# -Date Duplicated: 31,620,475
# -Date & -Count Duplicated: 31,986,289
# +BibNum Duplidated: 34,742,422

# %%
lots_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 lots_df
#
# NameError: name 'lots_df' is not defined

# %%
library_df.ISBN.str.split(',').str.len().sum()
# Out:
# np.float64(59991068.0)
