# %%
import pandas as pd

# %%
library_df = pd.read_csv('./datasets/library-collection-inventory/library-collection-inventory.csv')

# %%
collection_df = pd.read_excel('./datasets/library-collection-inventory/CollectionInventory_Codes_EXCLUDED_INCLUDED.xlsx')

# %%
type_df = pd.read_excel('./datasets/library-collection-inventory/CollectionInventory_Codes_EXCLUDED_INCLUDED.xlsx', sheet_name=1)

# %%
## Master Data Cleaning

# %%
# Only Keep Collection of Books
collection_df = collection_df[collection_df.FormatSubgroup == 'Book']

# %%
# Only Keep Books Types
type_df = type_df[type_df.FormatSubgroup == 'Book']

# %% [markdown]
# ## Data Cleansing

# %%
# Create dataframe for unique books only (dorpping date and item count)
books_df = library_df.drop(columns=['ReportDate', 'ItemCount']).drop_duplicates().copy()

# %%
# Drop item location
books_df.drop(columns=['ItemLocation'], inplace=True)
books_df.drop_duplicates(inplace=True)

# %%
# Drop NaN ISBN, Author, Title
books_df.dropna(subset=['ISBN'], inplace=True)

# %%
# Drop Floating Item (since it's not relevant)
books_df.drop(columns=['FloatingItem'], inplace=True)
books_df.drop_duplicates(inplace=True)

# %%
# impute NaN values as empty string
books_df.fillna('', inplace=True)

# %% [markdown]
# # Drop Item collection (since it is changing)
# books_df.drop(columns=['ItemCollection', 'FloatingItem'], inplace=True)
# books_df.drop_duplicates(inplace=True)

# %%
# Only Keep books that have a valid collection id (based on the book types)
books_df = books_df[books_df.ItemCollection.isin(collection_df.Code)]

# %%
# Only keep books that have a valid type id (based on book types)
books_df = books_df[books_df.ItemType.isin(type_df.Code)]

# %% [markdown]
# # Drop books with weird publication year (does not contain 4 digits number)
# library_df = library_df[library_df.PublicationYear.str.match(r'.*\d{4}.*')]

# %% [markdown]
# # Drop books with more than 4 ISBN values
# library_df = library_df[library_df.ISBN.str.split(',').str.len() <= 4].copy()

# %% [markdown]
# # Split the ISBN values into four columns (ISBN#)
# library_df[['ISBN1', 'ISBN2', 'ISBN3', 'ISBN4']] = library_df.ISBN.str.split(',', n=3, expand=True)

# %% [markdown]
# # Extract the first 4 digit number from publication year, and convert it to integer (ignore multiple years and characters)
# library_df['PublicationYear'] = library_df.PublicationYear.str.replace(r'^.*?(\d{4}).*$', r'\1', regex=True).astype(int)

# %% [markdown]
# library_df = library_df[library_df.PublicationYear >= 1000]

# %%
# Checkpoint
books_df.to_pickle('./books.pkl')

# %% [markdown]
# # Removing duplicated records
# library_df = library_df.drop_duplicates(subset=['BibNum'], keep='last')

# %%
# Remove duplicates based on BibNum
# -

# %%
books_df.shape
# Out:
# (1050667, 10)

# %%
books_df.BibNum.nunique()
# Out:
# 428624

# %%
books_df.BibNum.value_counts().head(10)
# Out:
# BibNum
# 493956     23
# 3297643    17
# 2647086    17
# 3272389    17
# 1959170    17
# 2749423    16
# 3263224    15
# 3346750    15
# 2932160    15
# 3228858    15
# Name: count, dtype: int64

# %%
books_df[books_df.BibNum == 493956]
# Out:
#           BibNum                                              Title  \
# 163591    493956  Historical atlas of Washington / by James W. S...
# 5189689   University of Oklahoma Press,
# 28537943  University of Oklahoma Press,
# 32621615  University of Oklahoma Press,
# 32644646  University of Oklahoma Press,
# 32876788  University of Oklahoma Press,
# 33333852  University of Oklahoma Press,
# 33436236  University of Oklahoma Press,
# 33458022  University of Oklahoma Press,
# 33999920  University of Oklahoma Press,
# 34034872  University of Oklahoma Press,
#
#                                                    Subjects ItemType  \
# 163591    Washington State Historical geography, Washing...     arbk
# 211589    Washington State Historical geography, Washing...     acbk
# 256861    Washington State Historical geography, Washing...     arbk
# 364443    Washington State Historical geography, Washing...     acbk
# 598237    Washington State Historical geography, Washing...     acbk
# 1036230   Washington State Historical geography, Washing...     acbk
# 1165747   Washington State Historical geography, Washing...     arbk
# 4177623   Washington State Historical geography, Washing...     arbk
# 4213260   Washington State Historical geography, Washing...     acbk
# 4306571   Washington State Historical geography, Washing...     acbk
# 4337869   Washington State Historical geography, Washing...     arbk
# 4648497   Washington State Historical geography, Washing...     acbk
# 4827299   Washington State Historical geography, Washing...     arbk
# 5189689   Washington State Historical geography, Washing...     acbk
# 28537943  Washington State Historical geography, Washing...     arbk
# 32621615  Washington State Historical geography, Washing...     acbk
# 32644646  Washington State Historical geography, Washing...     arbk
# 32876788  Washington State Historical geography, Washing...     arbk
# 33333852  Washington State Historical geography, Washing...     acbk
# 33436236  Washington State Historical geography, Washing...     acbk
# 33458022  Washington State Historical geography, Washing...     arbk
# 33999920  Washington State Historical geography, Washing...     acbk
# 34034872  Washington State Historical geography, Washing...     arbk
#
#          ItemCollection
# 163591           naatlr
# 211589          naatlas
# 256861            naref
# 364443             canf
# 598237           naatlr
# 1036230          naover
# 1165747          camapr
# 4177623          naatlr
# 4213260          naover
# 4306571         naatlas
# 4337869           naref
# 4648497          naatlr
# 4827299          camapr
# 5189689            canf
# 28537943          casea
# 32621615        naatlas
# 32644646         naatlr
# 32876788          naref
# 33333852         naatlr
# 33436236           canf
# 33458022         camapr
# 33999920         naover
# 34034872          casea

# %%
books_df[books_df.Author.str.contains('^Martin, George R. R.', case=False)].Author.value_counts()
# Out:
# Author
# Martin, George R. R.    90
# Name: count, dtype: int64

# %%
isbn_df = books_df[['BibNum', 'ISBN']].drop_duplicates().copy()

# %%
isbn_df.ISBN = isbn_df.ISBN.str.split(',')

# %%
isbn_df = isbn_df.explode(column='ISBN', ignore_index=True)

# %%
isbn_df.ISBN = isbn_df.ISBN.str.strip()

# %%
isbn_df.drop_duplicates(inplace=True)

# %%
(isbn_df.ISBN.value_counts()>2).sum()
# Out:
# np.int64(192)

# %%
books_df[books_df.BibNum.isin(list(isbn_df[isbn_df.ISBN == '9780195311808'].BibNum))]
# Out:
#           BibNum                                              Title  \
# 97812    2412114  John Brown / W.E.B. Du Bois ; introduction by ...
# 140423   2412180  The ordeal of Mansart / W.E.B. Du Bois ; intro...
# 153209   2411609  Africa, its geography, people, and products ; ...
# 227651   2412119  Mansart builds a school / W.E.B. Du Bois ; int...
# 4789064  Du Bois, W. E. B. (William Edward Burghardt), ...
# 4807095  Du Bois, W. E. B. (William Edward Burghardt), ...
# 5119038  Du Bois, W. E. B. (William Edward Burghardt), ...
# 5199062  Du Bois, W. E. B. (William Edward Burghardt), ...
# 5215141  Du Bois, W. E. B. (William Edward Burghardt), ...
# 5318652  Du Bois, W. E. B. (William Edward Burghardt), ...
#
#                                                       ISBN PublicationYear  \
# 97812    0195311809, 0195325745, 9780195311808, 9780195...          c2007.
# 140423   0195311809, 0195325869, 9780195311808, 9780195...          c2007.
# 153209   0195311809, 019532580X, 9780195311808, 9780195...          c2007.
# 227651   0195311809, 0195325877, 9780195311808, 9780195...          c2007.
# 238407   0195311809, 0195325729, 9780195311808, 9780195...          c2007.
# 246437   0195311809, 0195325834, 9780195311808, 9780195...          c2007.
# 269625   0195311809, 0195325710, 9780195311808, 9780195...          c2007.
# 290349   0195311809, 019532577X, 9780195311808, 9780195...          c2007.
# 494817   0195311809, 0195325761, 9780195311808, 9780195...          c2007.
# 558604   0195311809, 0195325826, 9780195311808, 9780195...          c2007.
# 728620   0195311809, 0195325788, 9780195311808, 9780195...          c2007.
# 983053   0195311809, 0195325842, 9780195311808, 9780195...           2007.
# 1176177  0195311809, 0195325893, 9780195311808, 9780195...          c2007.
# 1240003  0195311809, 0195325850, 9780195311808, 9780195...          c2007.
# 1251585  0195311809, 0195325796, 9780195311808, 9780195...          c2007.
# 4122007  0195311809, 0195325761, 9780195311808, 9780195...          [2007]
# 4160680  0195311809, 019532577X, 9780195311808, 9780195...          [2007]
# 4343491  0195311809, 0195325729, 9780195311808, 9780195...          [2007]
# 4375898  0195311809, 0195325834, 9780195311808, 9780195...          [2007]
# 4386942  0195311809, 019532580X, 9780195311808, 9780195...          [2007]
# 4636263  0195311809, 0195325869, 9780195311808, 9780195...          [2007]
# 4698198  0195311809, 0195325877, 9780195311808, 9780195...          [2007]
# 4736201  0195311809, 0195325788, 9780195311808, 9780195...          [2007]
# 4789064  0195311809, 0195325826, 9780195311808, 9780195...          [2007]
# 4807095  0195311809, 0195325710, 9780195311808, 9780195...          [2007]
# 5119038  0195311809, 0195325796, 9780195311808, 9780195...          [2007]
# 5199062  0195311809, 0195325893, 9780195311808, 9780195...          [2007]
# 5215141  0195311809, 0195325745, 9780195311808, 9780195...          [2007]
# 5318652  0195311809, 0195325850, 9780195311808, 9780195...          [2007]
#
#                         Publisher  \
# 97812    Oxford University Press,
# 140423   Oxford University Press,
# 153209   Oxford University Press,
# 227651   Oxford University Press,
# 238407   Oxford University Press,
# 246437   Oxford University Press,
# 269625   Oxford University Press,
# 290349   Oxford University Press,
# 494817   Oxford University Press,
# 558604   Oxford University Press,
# 728620   Oxford University Press,
# 983053   Oxford University Press,
# 1176177  Oxford University Press,
# 1240003  Oxford University Press,
# 1251585  Oxford University Press,
# 4122007  Oxford University Press,
# 4160680  Oxford University Press,
# 4343491  Oxford University Press,
# 4375898  Oxford University Press,
# 4386942  Oxford University Press,
# 4636263  Oxford University Press,
# 4698198  Oxford University Press,
# 4736201  Oxford University Press,
# 4789064  Oxford University Press,
# 4807095  Oxford University Press,
# 5119038  Oxford University Press,
# 5199062  Oxford University Press,
# 5215141  Oxford University Press,
# 5318652  Oxford University Press,
#
#                                                   Subjects ItemType  \
# 97812    Brown John 1800 1859, Abolitionists United Sta...     acbk
# 140423   African Americans Southern States Fiction, Afr...     acbk
# 153209                            Africa, Africa Geography     acbk
# 227651                           African Americans Fiction     acbk
# 238407   African Americans Social conditions, Africa Am...     acbk
# 246437   Du Bois W E B William Edward Burghardt 1868 19...     acbk
# 269625                   Slave trade United States History     acbk
# 290349     African Americans, United States Race relations     acbk
# 494817                                          Black race     acbk
# 558604                                  Black race, Blacks     acbk
# 728620   African Americans History, United States Race ...     acbk
# 983053                                      Africa History     acbk
# 1176177  Du Bois W E B William Edward Burghardt 1868 19...     acbk
# 1240003  Peace Information Center, Peace, United States...     acbk
# 1251585  African American medical students Fiction, Afr...     acbk
# 4122007                                         Black race     acbk
# 4160680    African Americans, United States Race relations     acbk
# 4343491  African Americans Social conditions, African A...     acbk
# 4375898  Du Bois W E B William Edward Burghardt 1868 19...     acbk
# 4386942                           Africa, Africa Geography     acbk
# 4636263  African Americans Southern States Fiction, Afr...     acbk
# 4698198                          African Americans Fiction     acbk
# 4736201  African Americans History, United States Race ...     acbk
# 4789064                                 Black race, Blacks     acbk
# 4807095                  Slave trade United States History     acbk
# 5119038  African American medical students Fiction, Afr...     acbk
# 5199062  Du Bois W E B William Edward Burghardt 1868 19...     acbk
# 5215141  Brown John 1800 1859, Abolitionists United Sta...     acbk
# 5318652  Peace Information Center, Peace, United States...     acbk
#
#         ItemCollection
# 97812            naaab
# 140423         naaafic
# 153209          naaanf
# 227651         naaafic
# 238407          naaanf
# 246437          naaanf
# 269625          naaanf
# 290349          naaanf
# 494817          naaanf
# 558604          naaanf
# 728620          naaanf
# 983053          naaanf
# 1176177          naaab
# 1240003         naaanf
# 1251585         naaanf
# 4122007         naaanf
# 4160680         naaanf
# 4343491         naaanf
# 4375898         naaanf
# 4386942         naaanf
# 4636263        naaafic
# 4698198        naaafic
# 4736201         naaanf
# 4789064         naaanf
# 4807095         naaanf
# 5119038         naaanf
# 5199062          naaab
# 5215141          naaab
# 5318652         naaanf

# %%
isbn_df.ISBN.str.len().value_counts()
# Out:
# ISBN
# 10    489352
# 13    322123
# 9        115
# 8         18
# 11         7
# 1          6
# 14         6
# 4          5
# 5          5
# 7          5
# 0          2
# 17         1
# 16         1
# 12         1
# 27         1
# 18         1
# 6          1
# 15         1
# Name: count, dtype: int64

# %%
isbn_df = isbn_df[isbn_df.ISBN != '']

# %%
isbn_df.to_pickle('./isbn.pkl')

# %%
gr_isbns_df = pd.read_pickle('./datasets/goodreads/gr_isbns.pkl')

# %%
(isbn_df.ISBN.isin(gr_isbns_df.isbn) | isbn_df.ISBN.isin(gr_isbns_df.isbn13)).sum()
# Out:
# np.int64(355119)

# %%
(gr_isbns_df.isbn.isin(isbn_df.ISBN) | gr_isbns_df.isbn13.isin(isbn_df.ISBN)).sum()
# Out:
# np.int64(194123)

# %%
(gr_isbns_df.isbn13.isin(gr_isbns_df.isbn)).sum()
# Out:
# np.int64(263)

# %%
((gr_isbns_df.isbn != '') & (gr_isbns_df.isbn.isin(gr_isbns_df.isbn13))).sum()
# Out:
# np.int64(20)

# %%
list(gr_isbns_df[((gr_isbns_df.isbn != '') & (gr_isbns_df.isbn.isin(gr_isbns_df.isbn13)))].isbn)
# Out:
# ['1622664051',
#  '1937007375',
#  '1439134006',
#  '0671578855',
#  '0803735006',
#  '1496400801',
#  '0374149208',
#  '1400033888',
#  '0062084267',
#  '1622662687',
#  '0385737947',
#  '0802130798',
#  '081013358X',
#  '1481469827',
#  '2253004219',
#  '0758280343',
#  '0316036234',
#  '0062245414',
#  '1482609509',
#  '0345391802']

# %%
library_df.shape
# Out:
# (35531308, 13)

# %%
books_df.shape
# Out:
# (1043224, 9)

# %%
isbn_df.BibNum.value_counts()
# Out:
# BibNum
# 3021717    88
# 66056      86
# 2403978    73
# 75511      62
# 3139646    52
#            ..
# 1847638     1
# 1837941     1
# 2361159     1
# 2057325     1
# 2164601     1
# Name: count, Length: 428624, dtype: int64

# %%
list(isbn_df[isbn_df.BibNum == 66056].ISBN)
# Out:
# ['0691015856',
#  '069104533X',
#  '0691045348',
#  '0691045356',
#  '0691045364',
#  '0691045372',
#  '0691045380',
#  '0691045399',
#  '0691045402',
#  '0691045410',
#  '0691045429',
#  '0691045437',
#  '0691045445',
#  '0691045453',
#  '0691045461',
#  '069104547X',
#  '0691045488',
#  '0691045496',
#  '0691045828',
#  '0691045836',
#  '0691046182',
#  '0691046867',
#  '0691046875',
#  '0691047286',
#  '0691047391',
#  '0691047766',
#  '0691047774',
#  '0691047782',
#  '0691047804',
#  '0691090432',
#  '0691094985',
#  '0691118957',
#  '0691124892',
#  '069112910X',
#  '0691135576',
#  '0691137730',
#  '0691137749',
#  '069115001X',
#  '069115323X',
#  '0691156719',
#  '0691160376',
#  '0691164207',
#  '0691170460',
#  '9780691015859',
#  '9780691045337',
#  '9780691045344',
#  '9780691045351',
#  '9780691045368',
#  '9780691045375',
#  '9780691045382',
#  '9780691045399',
#  '9780691045405',
#  '9780691045412',
#  '9780691045429',
#  '9780691045436',
#  '9780691045443',
#  '9780691045450',
#  '9780691045467',
#  '9780691045474',
#  '9780691045481',
#  '9780691045498',
#  '9780691045825',
#  '9780691045832',
#  '9780691046181',
#  '9780691046860',
#  '9780691046877',
#  '9780691047287',
#  '9780691047393',
#  '9780691047768',
#  '9780691047775',
#  '9780691047782',
#  '9780691047805',
#  '9780691090436',
#  '9780691094984',
#  '9780691118956',
#  '9780691124896',
#  '9780691129105',
#  '9780691135571',
#  '9780691137735',
#  '9780691137742',
#  '9780691150017',
#  '9780691153230',
#  '9780691156712',
#  '9780691160375',
#  '9780691164205',
#  '9780691170466']
